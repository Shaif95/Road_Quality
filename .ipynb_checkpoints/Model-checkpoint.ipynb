# %%
import os
from collections import Counter
import re

img_p = r"E:\Frame_Num\MatchedFrames"

cnt = Counter()

for fn in os.listdir(img_p):
    if not fn.lower().endswith(".jpg"):
        continue

    # filename format: video_name_frame_lane.jpg
    # example: 20250826_31302PMByGPSMapCamera_7_2.jpg
    m = re.search(r"_(\d+)\.jpg$", fn)
    if not m:
        continue

    lc = int(m.group(1))   # last number = lane_count
    if lc in [1, 2, 3, 4]:
        cnt[lc] = cnt[lc] + 1

print("=== Lane count distribution in MatchedFrames ===")
for k in [1, 2, 3, 4]:
    print(f"lane_count={k} : {cnt[k]}")
